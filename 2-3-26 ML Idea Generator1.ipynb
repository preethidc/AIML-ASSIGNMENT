# %% [markdown]
# #ML idea generator
# ##College
# #1.Student Performance Predictor Problem: Predict student marks or grade
# #Input → Output: Attendance, study hours, assignment scores → Final grade
#
# #2.Dropout Risk Detection Problem: Identify students likely to drop out
# #Input → Output: Attendance, GPA, fees status, engagement → Dropout risk (High/Medium/Low)
#
# #3.Course Recommendation System Problem: Suggest courses based on interest
# #Input → Output: Student interests, past subjects, grades → Recommended courses
#
# ##Healthcare
# #1.Disease Prediction System Problem: Predict possible disease
# #Input → Output: Symptoms, age, medical history → Disease prediction
#
# #2. Medicine Reminder App Problem: Predict best reminder schedule
# #Input → Output: Patient routine, prescription timing → Reminder schedule
#
# #3. Diabetes Risk Predictor Problem: Detect diabetes risk early
# #Input → Output: Blood sugar, BMI, age, lifestyle → Diabetes risk (Yes/No)
#
# ##Shopping
# #1.Product Recommendation System Problem: Suggest products users may like
# #Input → Output: User history, clicks, purchases → Recommended products
#
# #2.Price Prediction Model Problem: Predict product price
# #Input → Output: Brand, features, demand → Predicted price
