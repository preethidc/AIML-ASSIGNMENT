# %%
#Dataset detective

import pandas as pd

df = pd.read_csv("students.csv")

print("Top 5 rows:")
print(df.head())


max_values = df.max(numeric_only=True)
highest_column = max_values.idxmax()
print("\nHighest value column:", highest_column)
print("Highest value:", max_values.max())


print("\nMissing values in each column:")
print(df.isnull().sum())

#1.Top scorer is Sita with a total score of 277.
#2.Math has the highest average marks (87.60), meaning students performed best in this subject.
#3.Science has the lowest average marks (82.80),it may be slightly tougher for students.
#4.There are no missing values in the dataset.
#5.Marks range from 70 to 95, showing variation in student performance.
# Out:
# Top 5 rows:
#      Name  Math  Science  English
# 0    Asha    85       80       82
# 1     Raj    92       90       91
# 2   Meena    78       70       75
# 3  Vikram    88       85       87
# 4    Sita    95       89       93
#
# Highest value column: Math
# Highest value: 95
#
# Missing values in each column:
# Name       0
# Math       0
# Science    0
# English    0
# dtype: int64
