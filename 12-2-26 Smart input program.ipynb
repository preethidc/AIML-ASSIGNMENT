# %%
#SMART INPUT PROGRAM 

name=input("enter name:")
age=int(input("enter age:"))
hobby=input("enter hobby:")

if age <10:
    category="a child"
elif age <20:
    category="a teenager"
elif age <60:
    category="an adult"
else:
    category="a senior citizen"

print("Hello",name)
print("you are",age,"yrs old,so you are",category)
print(hobby,"is a good activity")
# Out:
# enter name: fghj
# enter age: 67
# enter hobby: reading
# Hello fghj
# you are 67 yrs old,so you are a senior citizen
# reading is a good activity
