# %%
#1st assignment
username=input("Enter username:")

if username =="preethi12":
    password=input("Enter password:")
    if password=="0987":
        print("logged in")
    else:
        print("password invalid")
else:
    print("invalid username")
# Out:
# Enter username: hjkh
# invalid username
